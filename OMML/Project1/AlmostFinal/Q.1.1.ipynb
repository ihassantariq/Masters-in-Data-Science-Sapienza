# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import functions_question_1_1 as f

import warnings
warnings.filterwarnings("ignore")

np.random.seed(1870543)

# %%
input_dim = 2
output_dim = 1
N = [24]#[i for i in range(8,25,4)]
S = [2.4]#[1,1.5,2,2.4]
R = [10e-5]#[10e-5,10e-4,10e-3]

x_train,y_train,x_test,y_test = f.data_set()
test_error, train_error, train_time, neurons, sigma, rho, w, v, b, FE, GE, error, terror = f.gridsearch(x_train,y_train,x_test,y_test, input_dim,output_dim,N,S,R)

print("The best number of neurons is ",neurons)
print("The best sigma is ",sigma)
print("The best rho is ",rho)

print('MSE = {}'.format(test_error))
print("\nTraining Finished")

#f.writejson("Q.1.1.json", w, b, v, neurons, sigma, rho)
#f.writetxt("output_question_1_1.txt", neurons, sigma, rho, "BFGS", train_error, test_error, train_time, FE, GE)
#f.ovunfit(N,S,R,sigma,rho,error,terror)
f.plotting('graph_question_1_1.png',w,b,v,sigma)
# Out:
# The best number of neurons is  24
# The best sigma is  2.4
# The best rho is  0.0001
# MSE = 0.0004221700912892197
#
# Training Finished

# %%
f.writejson("Q.1.1.json", w, b, v, neurons, sigma, rho)
f.writetxt("output_question_1_1.txt", neurons, sigma, rho, "BFGS", train_error, test_error, train_time, FE, GE)
# Out:
# Saving results in output_question_1_1.txt
